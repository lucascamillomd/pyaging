# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_atacseq.ipynb) [![Open In nbviewer](https://img.shields.io/badge/View%20in-nbviewer-orange)](https://nbviewer.jupyter.org/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_atacseq.ipynb)

# %% [markdown]
# # Bulk ATAC-Seq

# %% [markdown]
# This tutorial is a brief guide for the implementation of the two ATAC clocks developed by Morandini et al. Link to [paper](https://link.springer.com/article/10.1007/s11357-023-00986-0).

# %% [markdown]
# We just need two packages for this tutorial.

# %%
import pandas as pd
import pyaging as pya

# %% [markdown]
# ## Download and load example data

# %% [markdown]
# If you have your own ATAC-Seq data, please follow the recommendations in the Ocampo paper. Specifically, one needs to count the number of reads for each of the peak regions from the paper (file [here](https://static-content.springer.com/esm/art%3A10.1007%2Fs11357-023-00986-0/MediaObjects/11357_2023_986_MOESM9_ESM.tsv)). This can be done through the code found on their [GitHub](https://github.com/SunScript0/ATAC-clock/blob/main/pipeline_atac/02_peakset_and_counts.sh) using featureCounts.

# %% [markdown]
# For testing purposes, let's download an example of input for the ATAC clocks. For instructions on how to go from raw sequencing reads to the data table, please refer to the paper.

# %%
pya.data.download_example_data('GSE193140')
# Out:
# ⏺ example data already at pyaging_data/GSE193140.pkl
# 'pyaging_data/GSE193140.pkl'

# %%
df = pd.read_pickle('pyaging_data/GSE193140.pkl')

# %%
df.head()
# Out:
#         chr1:817100-817691  chr1:826742-828191  chr1:841908-843021  \
# CR_124                 182                2652                  15
# CR_122                  96                2688                  27
# CR_121                 137                2785                  42
# CR_120                 169                2819                  29
# CR_119                 205                3005                  18
#
#         chr1:844055-844921  chr1:857908-859108  chr1:869571-870271  \
# CR_124                  11                   9                 843
# CR_122                  25                  40                1097
# CR_121                  46                  69                1297
# CR_120                  35                  46                1373
# CR_119                  45                  37                1025
#
#         chr1:898378-899076  chr1:904303-905702  chr1:906675-907111  \
# CR_124                   2                 714                 556
# CR_122                  13                 786                 167
# CR_121                   8                 638                 351
# CR_120                  20                 931                 301
# CR_119                  33                1138                 241
#
#         chr1:912617-913368  ...  chrY:21073148-21074236  \
# CR_124                  37  ...                      62
# CR_122                  12  ...                      11
# CR_121                  24  ...                       0
# CR_120                  10  ...                       7
# CR_119                  36  ...                      15
#
#         chrY:21174455-21175401  chrY:21177324-21177828  \
# CR_124                     104                      65
# CR_122                      13                      31
# CR_121                       0                       0
# CR_120                       9                       8
# CR_119                      18                      17
#
#         chrY:21180682-21181317  chrY:21239902-21241040  \
# CR_124                      31                      90
# CR_122                      25                     270
# CR_121                       0                       0
# CR_120                      33                     151
# CR_119                      12                      57
#
#         chrY:21248553-21249961  chrY:21256824-21257260  \
# CR_124                      20                      50
# CR_122                      37                      29
# CR_121                       0                       0
# CR_120                      47                      50
# CR_119                      25                       7
#
#         chrY:21259823-21260874  chrY:22086084-22086722  chrY:22499696-22500344
# CR_124                      21                       2                       2
# CR_122                      18                       9                      12
# CR_121                       0                       0                       0
# CR_120                      18                      32                      14
# CR_119                       8                       7                       7
#
# [5 rows x 80400 columns]

# %% [markdown]
# ## Convert data to AnnData object

# %% [markdown]
# AnnData objects are highly flexible and are thus our preferred method of organizing data for age prediction.

# %%
adata = pya.preprocess.df_to_adata(df)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>AnnData: 157 samples × 80400 features · no missing values
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">  ⎿ </span><span style="color: #efc53f; text-decoration-color: #efc53f">⚠ </span><span style="color: #8a93a1; text-decoration-color: #8a93a1">No metadata provided. Leaving adata.obs empty</span>
# </pre>

# %% [markdown]
# Note that the original DataFrame is stored in `X_original` under layers. is This is what the `adata` object looks like:

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 157 × 80400
#     var: 'percent_na'
#     layers: 'X_original', None (.X)

# %% [markdown]
# ## Predict age

# %% [markdown]
# We can either predict one clock at once or all at the same time. For convenience, let's simply input all two clocks of interest at once. The function is invariant to the capitalization of the clock name.

# %%
pya.pred.predict_age(adata, ['OcampoATAC1', 'OcampoATAC2'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span><span style="font-weight: bold">predict_age</span><span style="color: #8a93a1; text-decoration-color: #8a93a1"> · 2 clocks · 157 samples · 1.3s · cpu · results in adata.obs</span>
# <span style="color: #2fbf71; text-decoration-color: #2fbf71">  ⏺ </span><span style="font-weight: bold">ocampoatac1</span><span style="color: #8a93a1; text-decoration-color: #8a93a1"> (0.7s)</span>
# <span style="color: #2fbf71; text-decoration-color: #2fbf71">  ⏺ </span><span style="font-weight: bold">ocampoatac2</span><span style="color: #8a93a1; text-decoration-color: #8a93a1"> (0.6s)</span>
# </pre>

# %%
adata.obs.head()
# Out:
#         ocampoatac1  ocampoatac2
# CR_124    29.527124    28.114206
# CR_122    39.003097    40.061162
# CR_121    40.716008    43.095199
# CR_120    32.380372    33.033456
# CR_119    36.440711    38.301516

# %% [markdown]
# After age prediction, the clocks are added to `adata.obs`. Moreover, the percent of missing values for each clock and other metadata are included in `adata.uns`.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 157 × 80400
#     obs: 'ocampoatac1', 'ocampoatac2'
#     var: 'percent_na'
#     uns: 'ocampoatac1_percent_na', 'ocampoatac1_missing_features', 'ocampoatac1_metadata', 'ocampoatac2_percent_na', 'ocampoatac2_missing_features', 'ocampoatac2_metadata'
#     layers: 'X_original', None (.X)

# %% [markdown]
# ## Get citation

# %% [markdown]
# The doi, citation, and some metadata are automatically added to the AnnData object under `adata.uns[CLOCKNAME_metadata]`.

# %%
adata.uns['ocampoatac1_metadata']
# Out:
# {'clock_name': 'ocampoatac1',
#  'data_type': 'chromatin accessibility',
#  'species': 'Homo sapiens',
#  'year': 2023,
#  'approved_by_author': '⌛',
#  'citation': 'Morandini, F. et al. ATAC-clock: An aging clock based on chromatin accessibility. GeroScience 46, 635-650 (2024).',
#  'doi': 'https://doi.org/10.1007/s11357-023-00986-0',
#  'notes': 'Published final ATAC-clock coefficient-table implementation using 228 open chromatin regions from the 80,400-region input peak set.',
#  'research_only': None,
#  'tissue': ['peripheral blood mononuclear cells'],
#  'predicts': ['chronological age'],
#  'training_target': ['chronological age'],
#  'unit': ['years'],
#  'model_type': 'elastic net regression',
#  'platform': ['ATAC-seq'],
#  'population': 'adults',
#  'journal': 'GeroScience',
#  'last_author': 'Alejandro Ocampo',
#  'n_features': 228,
#  'citations': 49,
#  'citations_date': '2026-07-05',
#  'version': 'v0.3.0',
#  'preprocess': 'tpm_norm_log1p'}
