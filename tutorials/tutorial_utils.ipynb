# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_utils.ipynb) [![Open In nbviewer](https://img.shields.io/badge/View%20in-nbviewer-orange)](https://nbviewer.jupyter.org/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_utils.ipynb)

# %% [markdown]
# # Search, cite, get metadata and clock parameters

# %% [markdown]
# This tutorial shows the use of some `pyaging` helper functions.

# %%
import pyaging as pya

# %% [markdown]
# ## Search

# %% [markdown]
# There are two main ways to search for a clock in `pyaging`. The first is through the doi of the paper in which the clock was developed.

# %%
pya.utils.find_clock_by_doi('https://doi.org/10.1038/s43587-022-00248-2')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>clocks with DOI https://doi.org/10.1038/s43587-022-00248-2: hrsinchphenoage, pcdnamtl, pcgrimage, pchannum,
# pchorvath2013, pcphenoage, pcskinandblood
# </pre>

# %% [markdown]
# The second way is by simply showing the names of all the clocks that are available.

# %%
pya.utils.show_all_clocks()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>177 clocks available
# abec                                  adbahadosingh                         altumage
# bitage                                bocklandt                             bohlin
# cabec                                 camilloh3k27ac                        camilloh3k27me3
# camilloh3k36me3                       camilloh3k4me1                        camilloh3k4me3
# camilloh3k9ac                         camilloh3k9me3                        camillopanhistone
# cellpopage                            compil6                               corticalclock
# cpgptgrimage3                         cpgptpcgrimage3                       ctsliver
# cvdwesterman                          deconvolutebloodepicbcell             deconvolutebloodepiccd4tcell
# deconvolutebloodepiccd8tcell          deconvolutebloodepicmonocyte          deconvolutebloodepicneutrophil
# deconvolutebloodepicnkcell            depressionbarbu                       dnamfili
# dnamfitage                            dnamfitagegait                        dnamfitagegrip
# dnamfitagevo2max                      dnamic                                dnamphenoage
# dnamstress                            dnamtl                                downsyndrome
# dunedinpace                           dunedinpoam38                         eabec
# encen100                              encen40                               ensembleagehumanmouse
# ensembleagestatic                     ensembleagestatictop                  epicga
# epicmithyper                          epicmithypo                           epitoc1
# epitoc2                               epitoc3                               garagnani
# gliasin                               grimage                               grimage2
# grimage2adm                           grimage2b2m                           grimage2cystatinc
# grimage2gdf15                         grimage2leptin                        grimage2loga1c
# grimage2logcrp                        grimage2packyrs                       grimage2pai1
# grimage2timp1                         han                                   hannum
# hep                                   hepatoxu                              homeostaticdysregulation
# horvath2013                           hrsinchphenoage                       hypoclock
# intrinclock                           kdmage                                knight
# leecontrol                            leerefinedrobust                      leerobust
# lin                                   linage2                               mammalian1
# mammalian2                            mammalian3                            mammalianblood2
# mammalianblood3                       mammalianfemale                       mammalianlifespan
# mammalianskin2                        mammalianskin3                        mayne
# mccartneyalcohol                      mccartneybmi                          mccartneybodyfat
# mccartneyeducation                    mccartneyhdlcholesterol               mccartneyldlcholesterol
# mccartneysmoking                      mccartneytotalcholesterol             mccartneytotalhdlratio
# mccartneywhr                          meer                                  neusin
# ocampoatac1                           ocampoatac2                           pasta
# pastamouse                            pcdnamtl                              pcgrimage
# pchannum                              pchorvath2013                         pcphenoage
# pcskinandblood                        pedbe                                 petkovich
# phenoage                              phenoagesaopaulo                      pipekelasticnet
# pipekfilteredh                        pipekretrainedh                       prostatecancerkirby
# reedbmi                               reg                                   replitali
# replitalinorm                         retroelementagev1                     retroelementagev2
# senchronoage                          sencultureage                         senmortalityage
# skinandblood                          stemtoc                               stemtocvitro
# stoch                                 stocp                                 stocz
# stubbs                                systemsage                            systemsageblood
# systemsagebrain                       systemsageheart                       systemsagehormone
# systemsageimmune                      systemsageinflammation                systemsagekidney
# systemsageliver                       systemsagelung                        systemsagemetabolic
# systemsagemusculoskeletal             tage                                  tagemortality
# thompson                              twelvecelldeconvolutebloodepicbas     twelvecelldeconvolutebloodepicbmem
# twelvecelldeconvolutebloodepicbnv     twelvecelldeconvolutebloodepiccd4mem  twelvecelldeconvolutebloodepiccd4nv
# twelvecelldeconvolutebloodepiccd8mem  twelvecelldeconvolutebloodepiccd8nv   twelvecelldeconvolutebloodepiceos
# twelvecelldeconvolutebloodepicmono    twelvecelldeconvolutebloodepicneu     twelvecelldeconvolutebloodepicnk
# twelvecelldeconvolutebloodepictreg    vidalbralo                            weidner
# wu                                    xchrom                                ychrom
# yingadaptage                          yingcausage                           yingdamage
# zhangblup                             zhangen                               zhangmortality
# </pre>

# %% [markdown]
# ## Cite

# %% [markdown]
# `pyaging` also provides citations for all available clocks.

# %%
pya.utils.cite_clock('AltumAge')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>citation for altumage
#   de Lima Camillo, L.P., Lapierre, L.R. &amp; Singh, R. A pan-tissue DNA-methylation epigenetic clock based on deep
# learning. npj Aging <span style="color: #008080; text-decoration-color: #008080; font-weight: bold">8</span>, <span style="color: #008080; text-decoration-color: #008080; font-weight: bold">4</span> <span style="font-weight: bold">(</span><span style="color: #008080; text-decoration-color: #008080; font-weight: bold">2022</span><span style="font-weight: bold">)</span>.
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">  Please also consider citing pyaging: de Lima Camillo, Lucas Paulo. "pyaging: a Python-based compendium of </span>
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">GPU-optimized aging clocks." bioRxiv (2023): 2023-11.</span>
# </pre>

# %% [markdown]
# ## Get metadata

# %% [markdown]
# To get all of the metadata for a clock, including citation and doi, just run the following.

# %%
pya.utils.get_clock_metadata('AltumAge')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>altumage metadata
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">clock_name</span>          altumage
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">data_type</span>           DNA methylation
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">species</span>             Homo sapiens
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">year</span>                2022
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">approved_by_author</span>  ✅
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">citation</span>            de Lima Camillo, L.P., Lapierre, L.R. &amp; Singh, R. A pan-tissue DNA-methylation epigenetic clock
#                     based on deep learning. npj Aging 8, 4 (2022).
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">doi</span>                 https://doi.org/10.1038/s41514-022-00085-y
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">notes</span>               Pan-tissue chronological-age predictor using a five-hidden-layer neural network and 20,318 CpGs
#                     shared across the 27K, 450K and EPIC manifests; the actual training data came from 27K and 450K
#                     datasets.
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">research_only</span>       None
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">tissue</span>              ['multi-tissue']
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">predicts</span>            ['chronological age']
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">training_target</span>     ['chronological age']
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">unit</span>                ['years']
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">model_type</span>          deep neural network
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">platform</span>            ['Illumina 27K', 'Illumina 450K']
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">population</span>          all ages
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">journal</span>             npj Aging
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">last_author</span>         Ritambhara Singh
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">n_features</span>          20318
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">citations</span>           145
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">citations_date</span>      2026-07-05
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">version</span>             v0.5.1
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">preprocess</span>          scale
# <span style="color: #8a93a1; text-decoration-color: #8a93a1">reference_values</span>    True
# </pre>

# %% [markdown]
# ## Get clock parameters

# %% [markdown]
# To easily analyze the weights and features of a particular clock, please use:

# %%
clock = pya.pred.load_clock('AltumAge')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #2fbf71; text-decoration-color: #2fbf71">⏺ </span>altumage ready on cpu
# </pre>

# %%
clock
# Out:
# AltumAge(
#   (base_model): AltumAgeNeuralNetwork(
#     (linear1): Linear(in_features=20318, out_features=32, bias=True)
#     (linear2): Linear(in_features=32, out_features=32, bias=True)
#     (linear3): Linear(in_features=32, out_features=32, bias=True)
#     (linear4): Linear(in_features=32, out_features=32, bias=True)
#     (linear5): Linear(in_features=32, out_features=32, bias=True)
#     (linear6): Linear(in_features=32, out_features=1, bias=True)
#     (bn1): BatchNorm1d(20318, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn2): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn3): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn4): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn5): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn6): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#   )
# )

# %% [markdown]
# Let's check the weights of the first linear layer for AltumAge.

# %%
clock.base_model.linear1.weight
# Out:
# Parameter containing:
# tensor([[ 1.2465e-05, -2.4719e-04,  5.4308e-02,  ..., -2.5304e-02,
#           5.2822e-02,  8.9800e-02],
#         [ 3.5401e-04, -3.0528e-03,  2.8799e-02,  ...,  6.8214e-03,
#           6.9691e-02,  1.2179e-01],
#         [ 1.6119e-04, -6.7272e-06, -4.6887e-02,  ...,  1.3132e-02,
#           9.2417e-02, -4.2074e-02],
#         ...,
#         [ 1.9902e-04,  9.0495e-04, -8.5197e-03,  ..., -9.6892e-02,
#           2.9396e-02,  5.9170e-02],
#         [-1.2038e-04,  3.7530e-04,  1.7924e-01,  ..., -4.9997e-02,
#          -1.2819e-02,  2.8045e-02],
#         [ 1.1584e-04,  2.2752e-04, -3.0746e-02,  ...,  1.7930e-02,
#           8.3116e-03, -2.0979e-02]], dtype=torch.float64, requires_grad=True)

# %% [markdown]
# A quick look at the features:

# %%
list(clock.features[0:10])
# Out:
# ['cg00000292',
#  'cg00002426',
#  'cg00003994',
#  'cg00007981',
#  'cg00008493',
#  'cg00008713',
#  'cg00009407',
#  'cg00011459',
#  'cg00012199',
#  'cg00012386']

# %% [markdown]
# And the reference values used:

# %%
list(clock.reference_values[0:10])
# Out:
# [np.float64(0.7598633952352156),
#  np.float64(0.7863788078967272),
#  np.float64(0.06324422321924528),
#  np.float64(0.029943418029386736),
#  np.float64(0.9363471225552753),
#  np.float64(0.05054944899168823),
#  np.float64(0.0351571456459043),
#  np.float64(0.9114132733331861),
#  np.float64(0.037064057665286136),
#  np.float64(0.039170308280475935)]

# %% [markdown]
# We can also get the metadata directly from the clock object:

# %%
clock.metadata
# Out:
# {'clock_name': 'altumage',
#  'data_type': 'DNA methylation',
#  'species': 'Homo sapiens',
#  'year': 2022,
#  'approved_by_author': '✅',
#  'citation': 'de Lima Camillo, L.P., Lapierre, L.R. & Singh, R. A pan-tissue DNA-methylation epigenetic clock based on deep learning. npj Aging 8, 4 (2022).',
#  'doi': 'https://doi.org/10.1038/s41514-022-00085-y',
#  'notes': 'Pan-tissue chronological-age predictor using a five-hidden-layer neural network and 20,318 CpGs shared across the 27K, 450K and EPIC manifests; the actual training data came from 27K and 450K datasets.',
#  'research_only': None,
#  'tissue': ['multi-tissue'],
#  'predicts': ['chronological age'],
#  'training_target': ['chronological age'],
#  'unit': ['years'],
#  'model_type': 'deep neural network',
#  'platform': ['Illumina 27K', 'Illumina 450K'],
#  'population': 'all ages',
#  'journal': 'npj Aging',
#  'last_author': 'Ritambhara Singh',
#  'n_features': 20318,
#  'citations': 145,
#  'citations_date': '2026-07-05',
#  'version': 'v0.5.1',
#  'preprocess': 'scale',
#  'reference_values': True}

# %% [markdown]
# And look at the units for each feature and expected range:

# %%
pya.utils.get_feature_ranges('phenoage')
# Out:
#                        feature           unit    low    high
# 0                      albumin            g/L  10.00    70.0
# 1                   creatinine         umol/L  10.00  3000.0
# 2                      glucose         mmol/L   1.00    60.0
# 3           c_reactive_protein          mg/dL   0.01    50.0
# 4           lymphocyte_percent              %   0.00   100.0
# 5             mean_cell_volume             fL  40.00   150.0
# 6  red_cell_distribution_width              %   8.00    40.0
# 7         alkaline_phosphatase            U/L   5.00  5000.0
# 8       white_blood_cell_count  10^3 cells/uL   0.05   500.0
# 9                          age          years   0.00   122.5

# %%
pya.utils.get_feature_ranges('horvath2013').head()
# Out:
#       feature        unit  low  high
# 0  cg00075967  beta value  0.0   1.0
# 1  cg00374717  beta value  0.0   1.0
# 2  cg00864867  beta value  0.0   1.0
# 3  cg00945507  beta value  0.0   1.0
# 4  cg01027739  beta value  0.0   1.0

# %% [markdown]
# For a more in depth look at how the clock was setup, including the model type and the source of the weights, please look at our [clocks notebook folder](https://github.com/lucascamillomd/pyaging/tree/main/clocks/notebooks) on GitHub.
