# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_utils.ipynb) [![Open In nbviewer](https://img.shields.io/badge/View%20in-nbviewer-orange)](https://nbviewer.jupyter.org/github/lucascamillomd/pyaging/blob/main/tutorials/tutorial_utils.ipynb)

# %% [markdown]
# # Search, cite, get metadata and clock parameters

# %% [markdown]
# This tutorial shows the use of some `pyaging` helper functions.

# %%
import pyaging as pya

# %% [markdown]
# ## Search

# %% [markdown]
# There are two main ways to search for a clock in `pyaging`. The first is through the doi of the paper in which the clock was developed.

# %%
pya.utils.find_clock_by_doi('https://doi.org/10.1038/s43587-022-00248-2')
# Out:
# |-----> 🏗️ Starting find_clock_by_doi function
# |-----> ⚙️ Load all clock metadata started
# |-----------> Data available at /Users/lucascamillo/.cache/huggingface/hub/models--lucascamillomd--pyaging-data/snapshots/18d637d2d6e58b65fa6b30f3743edd8b70253783/all_clock_metadata.pt
# |-----> ✅ Load all clock metadata finished [0.2270s]
# |-----> ⚙️ Searching for clock based on DOI started
# |-----------> in progress: 100.0000%
# |-----------> Clocks with DOI https://doi.org/10.1038/s43587-022-00248-2: hrsinchphenoage, pcdnamtl, pcgrimage, pchannum, pchorvath2013, pcphenoage, pcskinandblood
# |-----> ✅ Searching for clock based on DOI finished [0.2543s]
# |-----> 🎉 Done! [0.4856s]

# %% [markdown]
# The second way is by simply showing the names of all the clocks that are available.

# %%
pya.utils.show_all_clocks()
# Out:
# |-----> 🏗️ Starting show_all_clocks function
# |-----> ⚙️ Load all clock metadata started
# |-----------> Data available at /Users/lucascamillo/.cache/huggingface/hub/models--lucascamillomd--pyaging-data/snapshots/18d637d2d6e58b65fa6b30f3743edd8b70253783/all_clock_metadata.pt
# |-----> ✅ Load all clock metadata finished [0.1366s]
# |-----> ⚙️ Showing all available clock names started
# |-----------> abec
# |-----------> adbahadosingh
# |-----------> altumage
# |-----------> bitage
# |-----------> bocklandt
# |-----------> bohlin
# |-----------> cabec
# |-----------> camilloh3k27ac
# |-----------> camilloh3k27me3
# |-----------> camilloh3k36me3
# |-----------> camilloh3k4me1
# |-----------> camilloh3k4me3
# |-----------> camilloh3k9ac
# |-----------> camilloh3k9me3
# |-----------> camillopanhistone
# |-----------> cellpopage
# |-----------> compil6
# |-----------> corticalclock
# |-----------> cpgptgrimage3
# |-----------> cpgptpcgrimage3
# |-----------> ctsliver
# |-----------> cvdwesterman
# |-----------> deconvolutebloodepicbcell
# |-----------> deconvolutebloodepiccd4tcell
# |-----------> deconvolutebloodepiccd8tcell
# |-----------> deconvolutebloodepicmonocyte
# |-----------> deconvolutebloodepicneutrophil
# |-----------> deconvolutebloodepicnkcell
# |-----------> depressionbarbu
# |-----------> dnamfili
# |-----------> dnamfitage
# |-----------> dnamfitagegaitf
# |-----------> dnamfitagegaitm
# |-----------> dnamfitagegripf
# |-----------> dnamfitagegripm
# |-----------> dnamfitagevo2max
# |-----------> dnamic
# |-----------> dnamphenoage
# |-----------> dnamstress
# |-----------> dnamtl
# |-----------> downsyndrome
# |-----------> dunedinpace
# |-----------> dunedinpoam38
# |-----------> eabec
# |-----------> encen100
# |-----------> encen40
# |-----------> ensembleagehumanmouse
# |-----------> ensembleagestatic
# |-----------> ensembleagestatictop
# |-----------> epicga
# |-----------> epicmithyper
# |-----------> epicmithypo
# |-----------> epitoc1
# |-----------> epitoc2
# |-----------> epitoc3
# |-----------> garagnani
# |-----------> gliasin
# |-----------> grimage
# |-----------> grimage2
# |-----------> grimage2adm
# |-----------> grimage2b2m
# |-----------> grimage2cystatinc
# |-----------> grimage2gdf15
# |-----------> grimage2leptin
# |-----------> grimage2loga1c
# |-----------> grimage2logcrp
# |-----------> grimage2packyrs
# |-----------> grimage2pai1
# |-----------> grimage2timp1
# |-----------> han
# |-----------> hannum
# |-----------> hep
# |-----------> hepatoxu
# |-----------> horvath2013
# |-----------> hrsinchphenoage
# |-----------> hypoclock
# |-----------> intrinclock
# |-----------> knight
# |-----------> leecontrol
# |-----------> leerefinedrobust
# |-----------> leerobust
# |-----------> lin
# |-----------> mammalian1
# |-----------> mammalian2
# |-----------> mammalian3
# |-----------> mammalianblood2
# |-----------> mammalianblood3
# |-----------> mammalianfemale
# |-----------> mammalianlifespan
# |-----------> mammalianskin2
# |-----------> mammalianskin3
# |-----------> mayne
# |-----------> mccartneyalcohol
# |-----------> mccartneybmi
# |-----------> mccartneybodyfat
# |-----------> mccartneyeducation
# |-----------> mccartneyhdlcholesterol
# |-----------> mccartneyldlcholesterol
# |-----------> mccartneysmoking
# |-----------> mccartneytotalcholesterol
# |-----------> mccartneytotalhdlratio
# |-----------> mccartneywhr
# |-----------> meer
# |-----------> neusin
# |-----------> ocampoatac1
# |-----------> ocampoatac2
# |-----------> pasta
# |-----------> pastamouse
# |-----------> pcdnamtl
# |-----------> pcgrimage
# |-----------> pchannum
# |-----------> pchorvath2013
# |-----------> pcphenoage
# |-----------> pcskinandblood
# |-----------> pedbe
# |-----------> petkovich
# |-----------> phenoage
# |-----------> pipekelasticnet
# |-----------> pipekfilteredh
# |-----------> pipekretrainedh
# |-----------> prostatecancerkirby
# |-----------> reedbmi
# |-----------> reg
# |-----------> replitali
# |-----------> replitalinorm
# |-----------> retroelementagev1
# |-----------> retroelementagev2
# |-----------> senchronoage
# |-----------> sencultureage
# |-----------> senmortalityage
# |-----------> skinandblood
# |-----------> stemtoc
# |-----------> stemtocvitro
# |-----------> stoch
# |-----------> stocp
# |-----------> stocz
# |-----------> stubbs
# |-----------> systemsage
# |-----------> systemsageblood
# |-----------> systemsagebrain
# |-----------> systemsageheart
# |-----------> systemsagehormone
# |-----------> systemsageimmune
# |-----------> systemsageinflammation
# |-----------> systemsagekidney
# |-----------> systemsageliver
# |-----------> systemsagelung
# |-----------> systemsagemetabolic
# |-----------> systemsagemusculoskeletal
# |-----------> thompson
# |-----------> twelvecelldeconvolutebloodepicbas
# |-----------> twelvecelldeconvolutebloodepicbmem
# |-----------> twelvecelldeconvolutebloodepicbnv
# |-----------> twelvecelldeconvolutebloodepiccd4mem
# |-----------> twelvecelldeconvolutebloodepiccd4nv
# |-----------> twelvecelldeconvolutebloodepiccd8mem
# |-----------> twelvecelldeconvolutebloodepiccd8nv
# |-----------> twelvecelldeconvolutebloodepiceos
# |-----------> twelvecelldeconvolutebloodepicmono
# |-----------> twelvecelldeconvolutebloodepicneu
# |-----------> twelvecelldeconvolutebloodepicnk
# |-----------> twelvecelldeconvolutebloodepictreg
# |-----------> vidalbralo
# |-----------> weidner
# |-----------> wu
# |-----------> xchrom
# |-----------> ychrom
# |-----------> yingadaptage
# |-----------> yingcausage
# |-----------> yingdamage
# |-----------> zhangblup
# |-----------> zhangen
# |-----------> zhangmortality
# |-----> ✅ Showing all available clock names finished [0.3482s]
# |-----> 🎉 Done! [0.4893s]

# %% [markdown]
# ## Cite

# %% [markdown]
# `pyaging` also provides citations for all available clocks.

# %%
pya.utils.cite_clock('AltumAge')
# Out:
# |-----> 🏗️ Starting cite_clock function
# |-----> ⚙️ Load all clock metadata started
# |-----------> Data available at /Users/lucascamillo/.cache/huggingface/hub/models--lucascamillomd--pyaging-data/snapshots/18d637d2d6e58b65fa6b30f3743edd8b70253783/all_clock_metadata.pt
# |-----> ✅ Load all clock metadata finished [0.1361s]
# |-----> ⚙️ Searching for citation of clock altumage started
# |-----------> Citation for altumage:
# |-----------> de Lima Camillo, L.P., Lapierre, L.R. & Singh, R. A pan-tissue DNA-methylation epigenetic clock based on deep learning. npj Aging 8, 4 (2022).
# |-----------> Please also consider citing pyaging :)
# |-----------> de Lima Camillo, Lucas Paulo. "pyaging: a Python-based compendium of GPU-optimized aging clocks." bioRxiv (2023): 2023-11.
# |-----> ✅ Searching for citation of clock altumage finished [0.0306s]
# |-----> 🎉 Done! [0.1762s]

# %% [markdown]
# ## Get metadata

# %% [markdown]
# To get all of the metadata for a clock, including citation and doi, just run the following.

# %%
pya.utils.get_clock_metadata('AltumAge')
# Out:
# |-----> 🏗️ Starting get_clock_metadata function
# |-----> ⚙️ Load all clock metadata started
# |-----------> Data available at /Users/lucascamillo/.cache/huggingface/hub/models--lucascamillomd--pyaging-data/snapshots/18d637d2d6e58b65fa6b30f3743edd8b70253783/all_clock_metadata.pt
# |-----> ✅ Load all clock metadata finished [0.2578s]
# |-----> ⚙️ Showing altumage metadata started
# |-----------> clock_name: altumage
# |-----------> data_type: DNA methylation
# |-----------> species: Homo sapiens
# |-----------> year: 2022
# |-----------> approved_by_author: ✅
# |-----------> citation: de Lima Camillo, L.P., Lapierre, L.R. & Singh, R. A pan-tissue DNA-methylation epigenetic clock based on deep learning. npj Aging 8, 4 (2022).
# |-----------> doi: https://doi.org/10.1038/s41514-022-00085-y
# |-----------> notes: Pan-tissue chronological-age predictor using a five-hidden-layer neural network and 20,318 CpGs shared across the 27K, 450K and EPIC manifests; the actual training data came from 27K and 450K datasets.
# |-----------> research_only: None
# |-----------> tissue: ['multi-tissue']
# |-----------> predicts: ['chronological age']
# |-----------> training_target: ['chronological age']
# |-----------> unit: ['years']
# |-----------> model_type: deep neural network
# |-----------> platform: ['Illumina 27K', 'Illumina 450K']
# |-----------> population: all ages
# |-----------> journal: npj Aging
# |-----------> last_author: Ritambhara Singh
# |-----------> n_features: 20318
# |-----------> citations: 145
# |-----------> citations_date: 2026-07-05
# |-----------> version: v0.3.0
# |-----------> preprocess: scale
# |-----------> reference_values: True
# |-----> ✅ Showing altumage metadata finished [0.0200s]
# |-----> 🎉 Done! [0.2890s]

# %% [markdown]
# ## Get clock parameters

# %% [markdown]
# To easily analyze the weights and features of a particular clock, please use:

# %%
logger = pya.logger.Logger('test_logger')
device = 'cpu'
dir = 'pyaging_data'
indent_level = 1

clock = pya.pred.load_clock('AltumAge', device, dir, logger, indent_level=indent_level)
# Out:
# |-----> ⚙️ Load clock started
# |-----------> Data available at /Users/lucascamillo/.cache/huggingface/hub/models--pyaging--altumage/snapshots/3532a48f2ff7c0780f699065e0c2a1c6ab8629b9/altumage.pt
# |-----> ✅ Load clock finished [0.2560s]

# %%
clock
# Out:
# AltumAge(
#   (base_model): AltumAgeNeuralNetwork(
#     (linear1): Linear(in_features=20318, out_features=32, bias=True)
#     (linear2): Linear(in_features=32, out_features=32, bias=True)
#     (linear3): Linear(in_features=32, out_features=32, bias=True)
#     (linear4): Linear(in_features=32, out_features=32, bias=True)
#     (linear5): Linear(in_features=32, out_features=32, bias=True)
#     (linear6): Linear(in_features=32, out_features=1, bias=True)
#     (bn1): BatchNorm1d(20318, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn2): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn3): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn4): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn5): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#     (bn6): BatchNorm1d(32, eps=0.001, momentum=0.99, affine=True, bias=True, track_running_stats=True)
#   )
# )

# %% [markdown]
# Let's check the weights of the first linear layer for AltumAge.

# %%
clock.base_model.linear1.weight
# Out:
# Parameter containing:
# tensor([[ 1.2465e-05, -2.4719e-04,  5.4308e-02,  ..., -2.5304e-02,
#           5.2822e-02,  8.9800e-02],
#         [ 3.5401e-04, -3.0528e-03,  2.8799e-02,  ...,  6.8214e-03,
#           6.9691e-02,  1.2179e-01],
#         [ 1.6119e-04, -6.7272e-06, -4.6887e-02,  ...,  1.3132e-02,
#           9.2417e-02, -4.2074e-02],
#         ...,
#         [ 1.9902e-04,  9.0495e-04, -8.5197e-03,  ..., -9.6892e-02,
#           2.9396e-02,  5.9170e-02],
#         [-1.2038e-04,  3.7530e-04,  1.7924e-01,  ..., -4.9997e-02,
#          -1.2819e-02,  2.8045e-02],
#         [ 1.1584e-04,  2.2752e-04, -3.0746e-02,  ...,  1.7930e-02,
#           8.3116e-03, -2.0979e-02]], dtype=torch.float64, requires_grad=True)

# %% [markdown]
# A quick look at the features:

# %%
list(clock.features[0:10])
# Out:
# ['cg00000292',
#  'cg00002426',
#  'cg00003994',
#  'cg00007981',
#  'cg00008493',
#  'cg00008713',
#  'cg00009407',
#  'cg00011459',
#  'cg00012199',
#  'cg00012386']

# %% [markdown]
# And the reference values used:

# %%
list(clock.reference_values[0:10])
# Out:
# [np.float64(0.7598633952352156),
#  np.float64(0.7863788078967272),
#  np.float64(0.06324422321924528),
#  np.float64(0.029943418029386736),
#  np.float64(0.9363471225552753),
#  np.float64(0.05054944899168823),
#  np.float64(0.0351571456459043),
#  np.float64(0.9114132733331861),
#  np.float64(0.037064057665286136),
#  np.float64(0.039170308280475935)]

# %% [markdown]
# We can also get the metadata directly from the clock object:

# %%
clock.metadata
# Out:
# {'clock_name': 'altumage',
#  'data_type': 'DNA methylation',
#  'species': 'Homo sapiens',
#  'year': 2022,
#  'approved_by_author': '✅',
#  'citation': 'de Lima Camillo, L.P., Lapierre, L.R. & Singh, R. A pan-tissue DNA-methylation epigenetic clock based on deep learning. npj Aging 8, 4 (2022).',
#  'doi': 'https://doi.org/10.1038/s41514-022-00085-y',
#  'notes': 'Pan-tissue chronological-age predictor using a five-hidden-layer neural network and 20,318 CpGs shared across the 27K, 450K and EPIC manifests; the actual training data came from 27K and 450K datasets.',
#  'research_only': None,
#  'tissue': ['multi-tissue'],
#  'predicts': ['chronological age'],
#  'training_target': ['chronological age'],
#  'unit': ['years'],
#  'model_type': 'deep neural network',
#  'platform': ['Illumina 27K', 'Illumina 450K'],
#  'population': 'all ages',
#  'journal': 'npj Aging',
#  'last_author': 'Ritambhara Singh',
#  'n_features': 20318,
#  'citations': 145,
#  'citations_date': '2026-07-05',
#  'version': 'v0.3.0',
#  'preprocess': 'scale',
#  'reference_values': True}

# %% [markdown]
# For a more in depth look at how the clock was setup, including the model type and the source of the weights, please look at our [clocks notebook folder](https://github.com/lucascamillomd/pyaging/tree/main/clocks/notebooks) on GitHub.
